# %% [markdown]
# # Exercise 1

# %% [markdown]
# ### Create box plots on a single set of axes for all five experiments in the morley data set

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

data = pd.read_csv('morley.csv')

# Show the boxplot of Morley Data Set
# Show boxplot for all 5 experiments
sns.boxplot(x=data['Expt'], y=data['Speed'])

plt.xlabel('Experiment no.')
plt.ylabel('Speed of light (km/s)')
plt.title('Five experiments in the Morley Data Set')
plt.show()

# %% [markdown]
# # Exercise 2

# %% [markdown]
# ### Create box plots for all of the numercial variables in Fisher's Iris Data Set

# %%
# Resource: https://matplotlib.org/stable/plot_types/index
# Resource: http://seaborn.pydata.org/introduction.html#visualizing-dataset-structure

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
   
data = pd.read_csv('Iris-Data-Set.csv')

# Show the boxplot of Irish Data Set
# Show boxplot for all 4 columns
data.boxplot()

plt.title('Boxplot of each variable in the Iris Data Set')
plt.show()

# %%
# Split the boxplot for each column in the Iris Data Set

# Apply black background
plt.style.use("dark_background")

# Apply different colours per each class
colors = {"yellow", "orange", "red"}

# Show boxplot for Petal Width
sns.boxplot(x=data['class'], y=data['petal_width'], palette=colors)

plt.title('Petal Width for 3 Iris Classes')
plt.show()

# %%
# Show boxplot for Petal Lenght
sns.boxplot(x=data['class'], y=data['petal_length'], palette=colors)

plt.title('Petal Length for 3 Iris Classes')
plt.show()

# %%
# Show boxplot for Sepal Width
sns.boxplot(x=data['class'], y=data['sepal_width'], palette=colors)

plt.title('Sepal Width for 3 Iris Classes')
plt.show()

# %%
# Show boxplot for Sepal Lenght
sns.boxplot(x=data['class'], y=data['sepal_length'], palette=colors)

plt.title('Sepal Length for 3 Iris Classes')
plt.show()

# %% [markdown]
# # Exercise 3

# %% [markdown]
# ### Adapt the above code and plots so that the overall plot is inversely proportional and the individual groups are directly proportional

# %%
# resource: https://www.mathsisfun.com/algebra/directly-inversely-proportional.html

# %% [markdown]
# Directly proportional means that when one quantity increases (decreases), then the other quantity increases (decreases).

# %% [markdown]
# Inverse proportion means that when one quantity increases then the other quantity decreases and vice versa.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Code from Jupyter Notebook

# Create a series of x vectors.
xs = np.array([np.linspace(i, i + 2.0, 20) for i in range(10)])

# %%
# Create a corresponding series of y vectors.
ys = np.array([-1.0 * xs[i] + 2 * i for i in range(len(xs))])

# Add some noise.
ys = ys + np.random.normal(0.0, 1.0, ys.shape)

# %%
# Plot which is inversely proportional and the individual groups are directly proportional

for i in range(len(xs)):
    
    # Plot this category.
    plt.plot(xs[i], -ys[i], '.')
    
    # Fit line to category.
    m, c = np.polyfit(xs[i], -ys[i], 1)
    
    # Create steadily increasing x range for plot.
    xbestfit = np.linspace(xs[i].min(), xs[i].max(), 50)
    
    # Corresponding y values based on best fit line.
    ybestfit = m * xbestfit + c
    
    # Plot best fit line for category.
    plt.plot(xbestfit, ybestfit, color='lightgrey');
